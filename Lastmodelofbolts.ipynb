# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
import sklearn.linear_model as sk
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import svm
from sklearn.linear_model import LinearRegression

# %%
#!pip install numpy==1.17

# %%
raw_data = pd.read_csv('input_2.csv')
raw_data.fillna(raw_data.interpolate(),
                                    inplace=True)
x = raw_data[['Unit_4_Power', 'Unit_4_Reactive Power', 'Turbine_Guide Vane Opening',
       'Turbine_Pressure Drafttube', 'Turbine_Pressure Spiral Casing', 'Turbine_Rotational Speed']]
y = raw_data['Bolt_1_Steel tmp']
y2 = raw_data['Bolt_1_Tensile']
y3 = raw_data['Bolt_2_Tensile']
y4 = raw_data['Bolt_3_Tensile']
y5 = raw_data['Bolt_4_Tensile']
y6 = raw_data['Bolt_5_Tensile']
y7 = raw_data['Bolt_6_Tensile']
y8 = raw_data['Bolt_1_Torsion']
y9 = raw_data['Bolt_2_Torsion']
y10 = raw_data['Bolt_3_Torsion']
y11 = raw_data['Bolt_4_Torsion']
y12 = raw_data['Bolt_5_Torsion']
y13 = raw_data['Bolt_6_Torsion']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)
x_train, x_test, y2_train, y2_test = train_test_split(x, y2, test_size = 0.3)
x_train, x_test, y3_train, y3_test = train_test_split(x, y3, test_size = 0.3)
x_train, x_test, y4_train, y4_test = train_test_split(x, y4, test_size = 0.3)
x_train, x_test, y5_train, y5_test = train_test_split(x, y5, test_size = 0.3)
x_train, x_test, y6_train, y6_test = train_test_split(x, y6, test_size = 0.3)
x_train, x_test, y7_train, y7_test = train_test_split(x, y7, test_size = 0.3)
x_train, x_test, y8_train, y8_test = train_test_split(x, y8, test_size = 0.3)
x_train, x_test, y9_train, y9_test = train_test_split(x, y9, test_size = 0.3)
x_train, x_test, y10_train, y10_test = train_test_split(x, y10, test_size = 0.3)
x_train, x_test, y11_train, y11_test = train_test_split(x, y11, test_size = 0.3)
x_train, x_test, y12_train, y12_test = train_test_split(x, y12, test_size = 0.3)
x_train, x_test, y13_train, y13_test = train_test_split(x, y13, test_size = 0.3)

# %%
model = LinearRegression()
model2 = LinearRegression()
model3 = LinearRegression()
model4 = LinearRegression()
model5 = LinearRegression()
model6 = LinearRegression()
model7 = LinearRegression()
model8 = LinearRegression()
model9 = LinearRegression()
model10 = LinearRegression()
model11 = LinearRegression()
model12 = LinearRegression()
model13 = LinearRegression()

model.fit(x_train, y_train)
model2.fit(x_train, y2_train)
model3.fit(x_train, y3_train)
model4.fit(x_train, y4_train)
model5.fit(x_train, y5_train)
model6.fit(x_train, y6_train)
model7.fit(x_train, y7_train)
model8.fit(x_train, y8_train)
model9.fit(x_train, y9_train)
model10.fit(x_train, y10_train)
model11.fit(x_train, y11_train)
model12.fit(x_train, y12_train)
model13.fit(x_train, y13_train)


print(model.coef_)
print(model.intercept_)

pd.DataFrame(model.coef_, x.columns, columns = ['Coeff'])
pd.DataFrame(model2.coef_, x.columns, columns = ['Coeff'])
pd.DataFrame(model3.coef_, x.columns, columns = ['Coeff'])
pd.DataFrame(model4.coef_, x.columns, columns = ['Coeff'])
pd.DataFrame(model5.coef_, x.columns, columns = ['Coeff'])
pd.DataFrame(model6.coef_, x.columns, columns = ['Coeff'])
pd.DataFrame(model7.coef_, x.columns, columns = ['Coeff'])
pd.DataFrame(model8.coef_, x.columns, columns = ['Coeff'])
pd.DataFrame(model9.coef_, x.columns, columns = ['Coeff'])
pd.DataFrame(model10.coef_, x.columns, columns = ['Coeff'])
pd.DataFrame(model11.coef_, x.columns, columns = ['Coeff'])
pd.DataFrame(model12.coef_, x.columns, columns = ['Coeff'])
pd.DataFrame(model13.coef_, x.columns, columns = ['Coeff'])


predictions_1 = model.predict(x_test)
predictions_2 = model2.predict(x_test)
predictions_3 = model3.predict(x_test)
predictions_4 = model4.predict(x_test)
predictions_5 = model5.predict(x_test)
predictions_6 = model6.predict(x_test)
predictions_7 = model7.predict(x_test)
predictions_8 = model8.predict(x_test)
predictions_9 = model9.predict(x_test)
predictions_10 = model10.predict(x_test)
predictions_11 = model11.predict(x_test)
predictions_12 = model12.predict(x_test)
predictions_13 = model13.predict(x_test)
# Out:
# [-1.01431978e-04 -5.31099292e-05  4.47243127e-05 -1.16055514e-04
#  -4.14654499e-05  4.32021972e-04]
# 3.2704787192568743

# %%
raw_data2 = pd.read_csv('prediction_input.csv')

x2 = raw_data2[['Unit_4_Power', 'Unit_4_Reactive Power', 'Turbine_Guide Vane Opening',
       'Turbine_Pressure Drafttube', 'Turbine_Pressure Spiral Casing', 'Turbine_Rotational Speed']]

# %%
predictions = model.predict(x2)
predictions2 = model2.predict(x2)
predictions3 = model3.predict(x2)
predictions4 = model4.predict(x2)
predictions5 = model5.predict(x2)
predictions6 = model6.predict(x2)
predictions7 = model7.predict(x2)
predictions8 = model8.predict(x2)
predictions9 = model9.predict(x2)
predictions10 = model10.predict(x2)
predictions11 = model11.predict(x2)
predictions12 = model12.predict(x2)
predictions13 = model13.predict(x2)

number_of_elements = len(predictions)
number_of_elements2 = len(predictions2)

print("Number of elements in the list: ", number_of_elements)
print("Number of elements in the list: ", number_of_elements2)

array1 = pd.DataFrame(predictions)
array2 = pd.DataFrame(predictions2)
array3 = pd.DataFrame(predictions3)
array4 = pd.DataFrame(predictions4)
array5 = pd.DataFrame(predictions5)
array6 = pd.DataFrame(predictions6)
array7 = pd.DataFrame(predictions7)
array8 = pd.DataFrame(predictions8)
array9 = pd.DataFrame(predictions9)
array10 = pd.DataFrame(predictions10)
array11 = pd.DataFrame(predictions11)
array12 = pd.DataFrame(predictions12)
array13 = pd.DataFrame(predictions13)

xt = raw_data2[['timepoints','Unit_4_Power', 'Unit_4_Reactive Power', 'Turbine_Guide Vane Opening',
       'Turbine_Pressure Drafttube', 'Turbine_Pressure Spiral Casing', 'Turbine_Rotational Speed']]



#print(xt)
df = pd.DataFrame(list(zip(predictions, predictions2,predictions3,predictions4,predictions5,predictions6,predictions7,predictions8,predictions9,predictions10,predictions11,predictions12,predictions13,
)), columns=["Bolt_1_Steel tmp","Bolt_1_Tensile","Bolt_2_Tensile","Bolt_3_Tensile","Bolt_4_Tensile","Bolt_5_Tensile","Bolt_6_Tensile","Bolt_1_Torsion","Bolt_2_Torsion","Bolt_3_Torsion","Bolt_4_Torsion","Bolt_5_Torsion","Bolt_6_Torsion"])
#print(df)

result = pd.concat([xt, df], axis=1).reindex(xt.index)
print(result)
# Out:
# Number of elements in the list:  226364
# Number of elements in the list:  226364
#                  timepoints  Unit_4_Power  Unit_4_Reactive Power  \
# 0       1971-01-25 11:06:49    308.867868               5.592261
# 1       1971-01-25 11:06:50    308.898237               6.251969
# 2       1971-01-25 11:06:51    308.928605               7.037091
# 3       1971-01-25 11:06:52    308.958974               7.822213
# 4       1971-01-25 11:06:53    308.989343               8.607335
# 5       1971-01-25 11:06:54    309.019711               9.357542
# 6       1971-01-25 11:06:55    309.050080               9.025405
# 7       1971-01-25 11:06:56    309.080449               8.180861
# 8       1971-01-25 11:06:57    309.110817               7.336318
# 9       1971-01-25 11:06:58    309.141186               6.491774
# 10      1971-01-25 11:06:59    309.170490               5.665754
# 11      1971-01-25 11:07:00    309.161946               5.498128
# ...

# %%
result.to_csv('file_name2.csv')
